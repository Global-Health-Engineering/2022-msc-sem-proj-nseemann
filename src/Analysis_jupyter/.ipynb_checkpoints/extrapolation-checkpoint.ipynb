# %%
# %reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import statistics

numBin = 35

#Dump events
dump_arrival = pd.read_csv('../../data/raw_data/03_Skip_deliveries_at_Mzedi.csv')
dump_arrival = dump_arrival.drop(columns=['end','deviceid', 'start'])

#List of origin points
list_origin = dump_arrival.skip_origin.unique().astype(str)
list_origin = list_origin[list_origin!= 'nan']

#Datetime conversion and sorting
dump_arrival.date = pd.to_datetime(dump_arrival.date)#.dt.tz_localize('Africa/Mbabane')
dump_arrival = dump_arrival.sort_values('date')


## PIVOT TABLE
dump_arrival_new = dump_arrival.copy()
#dump_arrival_new['month'] = dump_arrival_new['date'].dt.month
#dump_arrival_new['year'] = dump_arrival_new['date'].dt.year
dump_arrival_new['values'] = 1
#print(dump_arrival_new)
new_pivot = pd.pivot_table(dump_arrival_new,values='values',index=['date'],columns='skip_origin',aggfunc=np.sum, fill_value=0)



## TIMELINE PLOT
#dates_arrival_skip = dump_arrival.loc[dump_arrival.skip_origin == list_origin[numBin]].sort_values('date').date
#print(dates_arrival_skip)
#print(len(dates_arrival_skip))
dates_arrival_skip = new_pivot[new_pivot[list_origin[numBin]]!=0].index
#plot timeline of dump arrivals from destination
fig, ax = plt.subplots(figsize=(8.8, 4), constrained_layout=True)
levels = np.tile([1,1], int(np.ceil(len(dates_arrival_skip)/2)))[:len(dates_arrival_skip)] #+1,-1 stems
ax.vlines(dates_arrival_skip, 0, levels, linestyle='solid', color=[(0, 0, 0, 0.5)], linewidth=2)  # The vertical stems
ax.plot(dates_arrival_skip, np.zeros_like(dates_arrival_skip), "-o", color="k", markerfacecolor="w")  #Tick plot
ax.yaxis.set_visible(False) #Hide y axis
ax.spines[["left", "top", "right"]].set_visible(False)#Hide other lines
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1)) #Month interval labels
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
ax.grid(True)
plt.title(list_origin[numBin])
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")
plt.show() #Plot

print(list_origin)
#Individual skip analysis: timeline, average, max, min, pattern <-- for specific periods to match skip raw data periods

#start,end,min, max, mean, median, mode
#period_start,period_end,min_period,max_period,median_period,mode_period

#Dump analysis: bar plot, pattern (week), average per week
time_start = pd.to_datetime('2021-10-01')
time_end = pd.to_datetime('2021-12-02')
#print(time_end)

skip_data = pd.DataFrame(np.zeros([len(list_origin),16]),columns=['start','end','#','min','max','mean','median','mode','period_start','period_end','#_period','min_period','max_period','mean_period','median_period','mode_period'], index=list_origin)
for columns in list_origin: #new_pivot
    current_skip = new_pivot[columns][new_pivot[columns]!=0]
    diff_0 = (current_skip[current_skip>1]-1).sum()
    current_skip_index_diff = current_skip.index.to_series().diff().dt.days.dropna().tolist()
    listofzeros = [0] * diff_0
    current_skip_index_diff.extend(listofzeros)
    skip_data.loc[columns,'start'] = current_skip.index.to_series().min()
    skip_data.loc[columns,'end'] = current_skip.index.to_series().max()
    skip_data.loc[columns,'#'] = len(current_skip)
    skip_data.loc[columns,'min'] = min(current_skip_index_diff)
    skip_data.loc[columns,'max'] = max(current_skip_index_diff)
    skip_data.loc[columns,'mean'] = statistics.mean(current_skip_index_diff)
    skip_data.loc[columns,'median'] = statistics.median(current_skip_index_diff)
    skip_data.loc[columns,'mode'] = statistics.mode(current_skip_index_diff)

    
    current_skip_period = current_skip[(current_skip.index >= time_start) & (current_skip.index <= time_end)]
    diff_0_period = (current_skip_period[current_skip_period>1]-1).sum()
    current_skip_period_index_diff = current_skip_period.index.to_series().diff().dt.days.dropna().tolist()
    listofzeros_period = [0] * diff_0_period
    current_skip_period_index_diff.extend(listofzeros)
    skip_data.loc[columns,'period_start'] = current_skip_period.index.to_series().min()
    skip_data.loc[columns,'period_end'] = current_skip_period.index.to_series().max()
    skip_data.loc[columns,'#_period'] = len(current_skip_period)
    skip_data.loc[columns,'min_period'] = min(current_skip_period_index_diff)
    skip_data.loc[columns,'max_period'] = max(current_skip_period_index_diff)
    skip_data.loc[columns,'mean_period'] = statistics.mean(current_skip_period_index_diff)
    skip_data.loc[columns,'median_period'] = statistics.median(current_skip_period_index_diff)
    skip_data.loc[columns,'mode_period'] = statistics.mode(current_skip_period_index_diff)
    break
print(skip_data)
#new_pivot['Bangwe ground'][new_pivot['Bangwe ground']!=0].index
# dump_arrival.loc[dump_arrival.skip_origin == 'BCA market'].sort_values('date').date
# agg_arrivals = dump_arrival.copy()
# agg_arrivals = agg_arrivals.drop(columns=['emptier type'])
# agg_arrivals = agg_arrivals.groupby([agg_arrivals['date'].dt.year.rename('year'), agg_arrivals['date'].dt.month.rename('month')]).count()#agg({'count'})
# agg_arrivals
#((dump_arrival.start-dump_arrival.date).dt.total_seconds()/3600).hist()
# newval = dump_arrival.end-dump_arrival.start
# series_deltas = newval.dt.total_seconds()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# ['Blantyre flea market' 'Queens Guardian shelter' 'Limbe flea market'
#  'Milowa' 'Limbe market' 'Kachere market' 'Pafumbi bus terminal'
#  'Chirimba market' 'Blantyre market' 'Chemusa market' 'Mbayani market'
#  'Bangwe ground' 'Khama market' 'Nanjiriri market' 'Mbwerela' 'Kayange'
#  'Limbe Hard Ware' 'Mibawa Bus terminals' 'Bangwe market'
#  'Chilomoni market' 'Thawale market' 'Ndirande market' 'Chilobwe'
#  'Kameza round a bout' 'Ndirande ground' 'Malekano' 'South Lunzu market'
#  'Nkolokoti market' 'Zingwangwa mosque' 'Zingwangwa water board'
#  'Soche market' 'Chiweto' 'Naizi market' 'BCA market'
#  'Wenela Bus terminal' 'Nancholi Police' 'Chimwankhunda mosque'
#  'Manase Market' 'Nthukwa market' 'Fargo']
# 2
#                                        start                  end      #  min  \
# Blantyre flea market     2020-12-05 00:00:00  2021-12-30 00:00:00  195.0  0.0
# Queens Guardian shelter                  0.0                  0.0    0.0  0.0
# Limbe flea market                        0.0                  0.0    0.0  0.0
# Milowa                                   0.0                  0.0    0.0  0.0
# Limbe market                             0.0                  0.0    0.0  0.0
# Kachere market                           0.0                  0.0    0.0  0.0
# Pafumbi bus terminal                     0.0                  0.0    0.0  0.0
# Chirimba market                          0.0                  0.0    0.0  0.0
# Blantyre market                          0.0                  0.0    0.0  0.0
# Chemusa market                           0.0                  0.0    0.0  0.0
# Mbayani market                           0.0                  0.0    0.0  0.0
# Bangwe ground                            0.0                  0.0    0.0  0.0
# Khama market                             0.0                  0.0    0.0  0.0
# Nanjiriri market                         0.0                  0.0    0.0  0.0
# Mbwerela                                 0.0                  0.0    0.0  0.0
# Kayange                                  0.0                  0.0    0.0  0.0
# Limbe Hard Ware                          0.0                  0.0    0.0  0.0
# Mibawa Bus terminals                     0.0                  0.0    0.0  0.0
# Bangwe market                            0.0                  0.0    0.0  0.0
# Chilomoni market                         0.0                  0.0    0.0  0.0
# Thawale market                           0.0                  0.0    0.0  0.0
# Ndirande market                          0.0                  0.0    0.0  0.0
# Chilobwe                                 0.0                  0.0    0.0  0.0
# Kameza round a bout                      0.0                  0.0    0.0  0.0
# Ndirande ground                          0.0                  0.0    0.0  0.0
# Malekano                                 0.0                  0.0    0.0  0.0
# South Lunzu market                       0.0                  0.0    0.0  0.0
# Nkolokoti market                         0.0                  0.0    0.0  0.0
# Zingwangwa mosque                        0.0                  0.0    0.0  0.0
# Zingwangwa water board                   0.0                  0.0    0.0  0.0
# Soche market                             0.0                  0.0    0.0  0.0
# Chiweto                                  0.0                  0.0    0.0  0.0
# Naizi market                             0.0                  0.0    0.0  0.0
# BCA market                               0.0                  0.0    0.0  0.0
# Wenela Bus terminal                      0.0                  0.0    0.0  0.0
# Nancholi Police                          0.0                  0.0    0.0  0.0
# Chimwankhunda mosque                     0.0                  0.0    0.0  0.0
# Manase Market                            0.0                  0.0    0.0  0.0
# Nthukwa market                           0.0                  0.0    0.0  0.0
# Fargo                                    0.0                  0.0    0.0  0.0
#
#                           max      mean  median  mode         period_start  \
# Blantyre flea market     38.0  1.902439     1.0   1.0  2021-10-01 00:00:00
# Queens Guardian shelter   0.0  0.000000     0.0   0.0                  0.0
# Limbe flea market         0.0  0.000000     0.0   0.0                  0.0
# Milowa                    0.0  0.000000     0.0   0.0                  0.0
# Limbe market              0.0  0.000000     0.0   0.0                  0.0
# Kachere market            0.0  0.000000     0.0   0.0                  0.0
# Pafumbi bus terminal      0.0  0.000000     0.0   0.0                  0.0
# Chirimba market           0.0  0.000000     0.0   0.0                  0.0
# Blantyre market           0.0  0.000000     0.0   0.0                  0.0
# Chemusa market            0.0  0.000000     0.0   0.0                  0.0
# Mbayani market            0.0  0.000000     0.0   0.0                  0.0
# Bangwe ground             0.0  0.000000     0.0   0.0                  0.0
# Khama market              0.0  0.000000     0.0   0.0                  0.0
# Nanjiriri market          0.0  0.000000     0.0   0.0                  0.0
# Mbwerela                  0.0  0.000000     0.0   0.0                  0.0
# Kayange                   0.0  0.000000     0.0   0.0                  0.0
# Limbe Hard Ware           0.0  0.000000     0.0   0.0                  0.0
# Mibawa Bus terminals      0.0  0.000000     0.0   0.0                  0.0
# Bangwe market             0.0  0.000000     0.0   0.0                  0.0
# Chilomoni market          0.0  0.000000     0.0   0.0                  0.0
# Thawale market            0.0  0.000000     0.0   0.0                  0.0
# Ndirande market           0.0  0.000000     0.0   0.0                  0.0
# Chilobwe                  0.0  0.000000     0.0   0.0                  0.0
# Kameza round a bout       0.0  0.000000     0.0   0.0                  0.0
# Ndirande ground           0.0  0.000000     0.0   0.0                  0.0
# Malekano                  0.0  0.000000     0.0   0.0                  0.0
# South Lunzu market        0.0  0.000000     0.0   0.0                  0.0
# Nkolokoti market          0.0  0.000000     0.0   0.0                  0.0
# Zingwangwa mosque         0.0  0.000000     0.0   0.0                  0.0
# Zingwangwa water board    0.0  0.000000     0.0   0.0                  0.0
# Soche market              0.0  0.000000     0.0   0.0                  0.0
# Chiweto                   0.0  0.000000     0.0   0.0                  0.0
# Naizi market              0.0  0.000000     0.0   0.0                  0.0
# BCA market                0.0  0.000000     0.0   0.0                  0.0
# Wenela Bus terminal       0.0  0.000000     0.0   0.0                  0.0
# Nancholi Police           0.0  0.000000     0.0   0.0                  0.0
# Chimwankhunda mosque      0.0  0.000000     0.0   0.0                  0.0
# Manase Market             0.0  0.000000     0.0   0.0                  0.0
# Nthukwa market            0.0  0.000000     0.0   0.0                  0.0
# Fargo                     0.0  0.000000     0.0   0.0                  0.0
#
#                                   period_end  #_period  min_period  \
# Blantyre flea market     2021-12-01 00:00:00      48.0         0.0
# Queens Guardian shelter                  0.0       0.0         0.0
# Limbe flea market                        0.0       0.0         0.0
# Milowa                                   0.0       0.0         0.0
# Limbe market                             0.0       0.0         0.0
# Kachere market                           0.0       0.0         0.0
# Pafumbi bus terminal                     0.0       0.0         0.0
# Chirimba market                          0.0       0.0         0.0
# Blantyre market                          0.0       0.0         0.0
# Chemusa market                           0.0       0.0         0.0
# Mbayani market                           0.0       0.0         0.0
# Bangwe ground                            0.0       0.0         0.0
# Khama market                             0.0       0.0         0.0
# Nanjiriri market                         0.0       0.0         0.0
# Mbwerela                                 0.0       0.0         0.0
# Kayange                                  0.0       0.0         0.0
# Limbe Hard Ware                          0.0       0.0         0.0
# Mibawa Bus terminals                     0.0       0.0         0.0
# Bangwe market                            0.0       0.0         0.0
# Chilomoni market                         0.0       0.0         0.0
# Thawale market                           0.0       0.0         0.0
# Ndirande market                          0.0       0.0         0.0
# Chilobwe                                 0.0       0.0         0.0
# Kameza round a bout                      0.0       0.0         0.0
