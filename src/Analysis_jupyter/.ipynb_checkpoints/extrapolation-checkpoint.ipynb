# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

numBin = 0

#Dump events
dump_arrival = pd.read_csv('../../data/raw_data/03_Skip_deliveries_at_Mzedi.csv')
dump_arrival = dump_arrival.drop(columns=['end','deviceid', 'start'])

#List of origin points
list_origin = dump_arrival.skip_origin.unique().astype(str)
list_origin = list_origin[list_origin!= 'nan']

#Datetime conversion and sorting
dump_arrival.date = pd.to_datetime(dump_arrival.date).dt.tz_localize('Africa/Mbabane')
dump_arrival = dump_arrival.sort_values('date')

dates_arrival_skip = dump_arrival.loc[dump_arrival.skip_origin == list_origin[numBin]].sort_values('date').date

#plot timeline of dump arrivals from destination
fig, ax = plt.subplots(figsize=(8.8, 4), constrained_layout=True)
levels = np.tile([-1,1], int(np.ceil(len(dates_arrival_skip)/2)))[:len(dates_arrival_skip)] #+1,-1 stems
ax.vlines(dates_arrival_skip, 0, levels, color="tab:red", linewidth=1)  # The vertical stems
ax.plot(dates_arrival_skip, np.zeros_like(dates_arrival_skip), "-o", color="k", markerfacecolor="w")  #Tick plot
ax.yaxis.set_visible(False) #Hide y axis
ax.spines[["left", "top", "right"]].set_visible(False)#Hide other lines
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1)) #Month interval labels
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")
plt.show() #Plot

dump_arrival_new = dump_arrival.copy()
dump_arrival_new['month'] = dump_arrival_new['date'].dt.month
dump_arrival_new['year'] = dump_arrival_new['date'].dt.year
dump_arrival_new['values'] = 1
dump_arrival_new = dump_arrival_new.drop(columns = 'date')
dump_arrival_new
new_pivot = pd.pivot_table(dump_arrival_new,values='values',index=['year','month'],columns='skip_origin',aggfunc=np.sum)
new_pivot
# agg_arrivals = dump_arrival.copy()
# agg_arrivals = agg_arrivals.drop(columns=['emptier type'])
# agg_arrivals = agg_arrivals.groupby([agg_arrivals['date'].dt.year.rename('year'), agg_arrivals['date'].dt.month.rename('month')]).count()#agg({'count'})
# agg_arrivals
#((dump_arrival.start-dump_arrival.date).dt.total_seconds()/3600).hist()
# newval = dump_arrival.end-dump_arrival.start
# series_deltas = newval.dt.total_seconds()
# Out:
# skip_origin  BCA market  Bangwe ground  Bangwe market  Blantyre flea market  \
# year month
# 2010 1              NaN            NaN            NaN                   NaN
# 2012 1              NaN            NaN            NaN                   NaN
# 2020 12             2.0            2.0            2.0                  12.0
# 2021 1              NaN            1.0            2.0                  14.0
#      2              NaN            NaN            1.0                   3.0
#      3              NaN            NaN            3.0                  20.0
#      4              NaN            NaN            NaN                  13.0
#      5              NaN            1.0            NaN                  10.0
#      6              1.0            1.0            2.0                  10.0
#      7              NaN            4.0            8.0                  18.0
#      8              NaN            3.0            6.0                  16.0
#      9              1.0            1.0            3.0                  21.0
#      10             NaN            NaN            1.0                  23.0
#      11             NaN            NaN            NaN                  26.0
#      12             NaN            1.0            3.0                  20.0
#
# skip_origin  Blantyre market  Chemusa market  Chilobwe  Chilomoni market  \
# year month
# 2010 1                   NaN             NaN       NaN               NaN
# 2012 1                   NaN             NaN       NaN               NaN
# 2020 12                  1.0             4.0       2.0               NaN
# 2021 1                   6.0             1.0       NaN               1.0
#      2                   2.0             1.0       NaN               NaN
#      3                  13.0             1.0       2.0               1.0
#      4                   7.0             2.0       NaN               1.0
#      5                   6.0             4.0       NaN               1.0
#      6                  13.0             5.0       NaN               NaN
#      7                  13.0            10.0       3.0               4.0
#      8                   8.0            12.0       NaN               6.0
#      9                  10.0             4.0       2.0               NaN
#      10                 10.0             7.0       NaN               1.0
#      11                  7.0             6.0       3.0               1.0
#      12                 10.0             3.0       1.0               NaN
#
# skip_origin  Chimwankhunda mosque  Chirimba market  ...  Nkolokoti market  \
# year month                                          ...
# 2010 1                        NaN              NaN  ...               NaN
# 2012 1                        NaN              NaN  ...               NaN
# 2020 12                       1.0              6.0  ...               1.0
# 2021 1                        NaN              7.0  ...               1.0
#      2                        NaN              1.0  ...               NaN
#      3                        NaN              7.0  ...               1.0
#      4                        NaN              2.0  ...               NaN
#      5                        NaN              6.0  ...               NaN
#      6                        NaN              2.0  ...               1.0
#      7                        NaN             12.0  ...               NaN
#      8                        1.0             20.0  ...               1.0
#      9                        1.0             18.0  ...               NaN
#      10                       NaN             13.0  ...               NaN
#      11                       NaN             16.0  ...               1.0
#      12                       NaN             14.0  ...               NaN
#
# skip_origin  Nthukwa market  Pafumbi bus terminal  Queens Guardian shelter  \
# year month
# 2010 1                  NaN                   NaN                      NaN
# 2012 1                  NaN                   NaN                      NaN
# 2020 12                 NaN                   3.0                      3.0
# 2021 1                  2.0                   2.0                      1.0
#      2                  NaN                   2.0                      1.0
#      3                  NaN                   NaN                      1.0
#      4                  2.0                   4.0                      1.0
#      5                  NaN                   1.0                      NaN
#      6                  NaN                   3.0                      NaN
#      7                  1.0                   1.0                      2.0
#      8                  NaN                   2.0                      2.0
#      9                  2.0                   2.0                      1.0
#      10                 1.0                   3.0                      1.0
#      11                 1.0                   2.0                      6.0
#      12                 NaN                   4.0                      NaN
#
# skip_origin  Soche market  South Lunzu market  Thawale market  \
# year month
# 2010 1                NaN                 NaN             NaN
# 2012 1                NaN                 NaN             NaN
# 2020 12               1.0                 2.0             3.0
# 2021 1                NaN                 NaN             NaN
#      2                NaN                 NaN             NaN
#      3                1.0                 NaN             3.0
#      4                NaN                 1.0             NaN
#      5                NaN                 NaN             1.0
#      6                NaN                 3.0             NaN
#      7                2.0                 1.0             4.0
#      8                NaN                 NaN             4.0
#      9                2.0                 NaN             1.0
#      10               NaN                 1.0             2.0
#      11               1.0                 NaN             3.0
#      12               1.0                 2.0             NaN
#
# skip_origin  Wenela Bus terminal  Zingwangwa mosque  Zingwangwa water board
# year month
# 2010 1                       NaN                NaN                     NaN
# 2012 1                       NaN                NaN                     NaN
# 2020 12                      1.0                1.0                     1.0
# 2021 1                       1.0                1.0                     NaN
#      2                       NaN                1.0                     1.0
#      3                       NaN                NaN                     2.0
#      4                       NaN                1.0                     NaN
#      5                       NaN                NaN                     NaN
#      6                       NaN                NaN                     NaN
#      7                       1.0                NaN                     2.0
#      8                       2.0                1.0                     1.0
#      9                       NaN                NaN                     NaN
#      10                      1.0                1.0                     NaN
#      11                      2.0                1.0                     1.0
#      12                      1.0                NaN                     NaN
#
# [15 rows x 40 columns]
